# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
x=pd.read_csv(r"C:\Users\vidya\Downloads\Thyroid_Diff.csv")
x
# Out:
#      Age Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27      F      No         No              No                 Euthyroid
# 1     34      F      No        Yes              No                 Euthyroid
# 2     30      F      No         No              No                 Euthyroid
# 3     62      F      No         No              No                 Euthyroid
# 4     62      F      No         No              No                 Euthyroid
# ..   ...    ...     ...        ...             ...                       ...
# 378   72      M     Yes        Yes             Yes                 Euthyroid
# 379   81      M     Yes         No             Yes                 Euthyroid
# 380   72      M     Yes        Yes              No                 Euthyroid
# 381   61      M     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67      M     Yes         No              No                 Euthyroid
#
# ...

# %%
x.shape
# Out:
# (383, 17)

# %%
x.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# Stage                   0
# Response                0
# Recurred                0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    object
#  2   Smoking               383 non-null    object
#  3   Hx Smoking            383 non-null    object
#  4   Hx Radiothreapy       383 non-null    object
#  5   Thyroid Function      383 non-null    object
#  6   Physical Examination  383 non-null    object
#  7   Adenopathy            383 non-null    object
#  8   Pathology             383 non-null    object
#  9   Focality              383 non-null    object
#  10  Risk                  383 non-null    object
#  11  T                     383 non-null    object
#  12  N                     383 non-null    object
#  13  M                     383 non-null    object
#  14  Stage                 383 non-null    object
# ...

# %%
x["Age"].unique()
# Out:
# array([27, 34, 30, 62, 52, 41, 46, 51, 40, 75, 59, 49, 50, 76, 42, 44, 43,
#        36, 70, 60, 33, 26, 37, 55, 31, 45, 20, 38, 29, 25, 21, 23, 24, 35,
#        54, 22, 69, 28, 17, 73, 18, 39, 57, 66, 32, 47, 56, 63, 19, 67, 72,
#        61, 68, 48, 81, 53, 58, 80, 79, 65, 15, 82, 71, 64, 78],
#       dtype=int64)

# %%
x["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
x["Gender"]=x["Gender"].map({"M":1,"F":0})

# %%
x
# Out:
#      Age  Gender Smoking Hx Smoking Hx Radiothreapy          Thyroid Function  \
# 0     27       0      No         No              No                 Euthyroid
# 1     34       0      No        Yes              No                 Euthyroid
# 2     30       0      No         No              No                 Euthyroid
# 3     62       0      No         No              No                 Euthyroid
# 4     62       0      No         No              No                 Euthyroid
# ..   ...     ...     ...        ...             ...                       ...
# 378   72       1     Yes        Yes             Yes                 Euthyroid
# 379   81       1     Yes         No             Yes                 Euthyroid
# 380   72       1     Yes        Yes              No                 Euthyroid
# 381   61       1     Yes        Yes             Yes  Clinical Hyperthyroidism
# 382   67       1     Yes         No              No                 Euthyroid
#
# ...

# %%
x["Smoking"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
x["Smoking"]=x["Smoking"].map({"Yes":1,"No":0})

# %%
x
# Out:
#      Age  Gender  Smoking Hx Smoking Hx Radiothreapy  \
# 0     27       0        0         No              No
# 1     34       0        0        Yes              No
# 2     30       0        0         No              No
# 3     62       0        0         No              No
# 4     62       0        0         No              No
# ..   ...     ...      ...        ...             ...
# 378   72       1        1        Yes             Yes
# 379   81       1        1         No             Yes
# 380   72       1        1        Yes              No
# 381   61       1        1        Yes             Yes
# 382   67       1        1         No              No
#
#              Thyroid Function         Physical Examination Adenopathy  \
# 0                   Euthyroid   Single nodular goiter-left         No
# 1                   Euthyroid          Multinodular goiter         No
# 2                   Euthyroid  Single nodular goiter-right         No
# ...

# %%
x["Thyroid Function"].unique()
# Out:
# array(['Euthyroid', 'Clinical Hyperthyroidism', 'Clinical Hypothyroidism',
#        'Subclinical Hyperthyroidism', 'Subclinical Hypothyroidism'],
#       dtype=object)

# %%
x["Hx Smoking"]=x["Hx Smoking"].map({"Yes":1,"No":0})
x["Hx Radiothreapy"]=x["Hx Radiothreapy"].map({"Yes":1,"No":0})

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  \
# 0     27       0        0           0                0
# 1     34       0        0           1                0
# 2     30       0        0           0                0
# 3     62       0        0           0                0
# 4     62       0        0           0                0
# ..   ...     ...      ...         ...              ...
# 378   72       1        1           1                1
# 379   81       1        1           0                1
# 380   72       1        1           1                0
# 381   61       1        1           1                1
# 382   67       1        1           0                0
#
#              Thyroid Function         Physical Examination Adenopathy  \
# 0                   Euthyroid   Single nodular goiter-left         No
# 1                   Euthyroid          Multinodular goiter         No
# 2                   Euthyroid  Single nodular goiter-right         No
# ...

# %%
x["Thyroid Function"].unique()
# Out:
# array(['Euthyroid', 'Clinical Hyperthyroidism', 'Clinical Hypothyroidism',
#        'Subclinical Hyperthyroidism', 'Subclinical Hypothyroidism'],
#       dtype=object)

# %%
x["Thyroid Function"]=x["Thyroid Function"].map({"Euthyroid":1,"Clinical Hyperthyroidism":0,"Clinical Hypothyroidism":1,"Subclinical Hyperthyroidism":0,"Subclinical Hypothyroidism":1})
x["Thyroid Function"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 378    1
# 379    1
# 380    1
# 381    0
# 382    1
# Name: Thyroid Function, Length: 383, dtype: int64

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#             Physical Examination Adenopathy       Pathology     Focality  \
# ...

# %%
x["Physical Examination"].unique()
# Out:
# array(['Single nodular goiter-left', 'Multinodular goiter',
#        'Single nodular goiter-right', 'Normal', 'Diffuse goiter'],
#       dtype=object)

# %%
x["Physical Examination"]=x["Physical Examination"].apply(lambda i:i.replace("Single nodular goiter-left","1"))
x["Physical Examination"]=x["Physical Examination"].apply(lambda i:i.replace("Multinodular goiter","0"))
x["Physical Examination"]=x["Physical Examination"].apply(lambda i:i.replace("Single nodular goiter-right","0"))
x["Physical Examination"]=x["Physical Examination"].apply(lambda i:i.replace("Normal","1"))
x["Physical Examination"]=x["Physical Examination"].apply(lambda i:i.replace("Diffuse goiter","0"))

# %%
x["Physical Examination"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    0
# 379    0
# 380    0
# 381    0
# 382    0
# Name: Physical Examination, Length: 383, dtype: object

# %%
x["Physical Examination"]=x["Physical Examination"].astype("int")

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination Adenopathy       Pathology     Focality  Risk    T  \
# ...

# %%
x["Adenopathy"].unique()
# Out:
# array(['No', 'Right', 'Extensive', 'Left', 'Bilateral', 'Posterior'],
#       dtype=object)

# %%
x["Adenopathy"]=x["Adenopathy"].apply(lambda i:i.replace("No","0"))
x["Adenopathy"]=x["Adenopathy"].apply(lambda i:i.replace("Right","1"))
x["Adenopathy"]=x["Adenopathy"].apply(lambda i:i.replace("Extensive","1"))
x["Adenopathy"]=x["Adenopathy"].apply(lambda i:i.replace("Left","0"))
x["Adenopathy"]=x["Adenopathy"].apply(lambda i:i.replace("Bilateral","1"))
x["Adenopathy"]=x["Adenopathy"].apply(lambda i:i.replace("Posterior","0"))
x["Adenopathy"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    1
# 379    1
# 380    1
# 381    1
# 382    1
# Name: Adenopathy, Length: 383, dtype: object

# %%
x["Adenopathy"]=x["Adenopathy"].astype("int")

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy       Pathology     Focality  Risk    T  \
# ...

# %%
x["Pathology"].unique()
# Out:
# array(['Micropapillary', 'Papillary', 'Follicular', 'Hurthel cell'],
#       dtype=object)

# %%
x["Pathology"]=x["Pathology"].apply(lambda i:i.replace("Micropapillary","0"))
x["Pathology"]=x["Pathology"].apply(lambda i:i.replace("Papillary","1"))
x["Pathology"]=x["Pathology"].apply(lambda i:i.replace("Follicular","1"))
x["Pathology"]=x["Pathology"].apply(lambda i:i.replace("Hurthel cell","0"))

# %%
x["Pathology"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    1
# 379    1
# 380    1
# 381    0
# 382    1
# Name: Pathology, Length: 383, dtype: object

# %%
x["Pathology"]=x["Pathology"].astype("int")

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy  Pathology     Focality  Risk    T    N  \
# ...

# %%
x["Focality"].unique()
# Out:
# array(['Uni-Focal', 'Multi-Focal'], dtype=object)

# %%
x["Focality"]=x["Focality"].apply(lambda i:i.replace("Uni-Focal","1"))
x["Focality"]=x["Focality"].apply(lambda i:i.replace("Multi-Focal","0"))
x["Focality"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 378    1
# 379    0
# 380    0
# 381    0
# 382    0
# Name: Focality, Length: 383, dtype: object

# %%
x["Focality"]=x["Focality"].astype("int")

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk    T    N  \
# ...

# %%
x.columns
# Out:
# Index(['Age', 'Gender', 'Smoking', 'Hx Smoking', 'Hx Radiothreapy',
#        'Thyroid Function', 'Physical Examination', 'Adenopathy', 'Pathology',
#        'Focality', 'Risk', 'T', 'N', 'M', 'Stage', 'Response', 'Recurred'],
#       dtype='object')

# %%
x["Risk"].unique()
# Out:
# array(['Low', 'Intermediate', 'High'], dtype=object)

# %%
x["Risk"]=x["Risk"].map({"High":3,"Intermediate":2,"Low":1})
x["Risk"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 378    3
# 379    3
# 380    3
# 381    3
# 382    3
# Name: Risk, Length: 383, dtype: int64

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk    T    N  \
# ...

# %%
x["T"].unique()
# Out:
# array(['T1a', 'T1b', 'T2', 'T3a', 'T3b', 'T4a', 'T4b'], dtype=object)

# %%
x["T"]=x["T"].map({"T1a":1,"T1b":0,"T2":1,"T3a":0,"T3b":1,"T4a":0,"T4b":1})
x["T"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 378    1
# 379    1
# 380    1
# 381    1
# 382    1
# Name: T, Length: 383, dtype: int64

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk  T    N   M  \
# ...

# %%
x["N"].unique()
# Out:
# array(['N0', 'N1b', 'N1a'], dtype=object)

# %%
x["N"]=x["N"].map({"N0":0,"N1b":2,"N1a":1})
x["N"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    2
# 379    2
# 380    2
# 381    2
# 382    2
# Name: N, Length: 383, dtype: int64

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk  T  N   M  \
# ...

# %%
x["M"].unique()
# Out:
# array(['M0', 'M1'], dtype=object)

# %%
x["M"]=x["M"].map({"M0":0,"M1":1})
x["M"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 378    1
# 379    1
# 380    1
# 381    0
# 382    0
# Name: M, Length: 383, dtype: int64

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk  T  N  M  \
# ...

# %%
x["Stage"].unique()
# Out:
# array(['I', 'II', 'IVB', 'III', 'IVA'], dtype=object)

# %%
x.drop(columns="Stage",inplace=True)

# %%
x["Response"].unique()
# Out:
# array(['Indeterminate', 'Excellent', 'Structural Incomplete',
#        'Biochemical Incomplete'], dtype=object)

# %%
x.drop(columns="Response",inplace=True)

# %%
x.drop(columns="Recurred",inplace=True)

# %%
x.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Smoking                 0
# Hx Smoking              0
# Hx Radiothreapy         0
# Thyroid Function        0
# Physical Examination    0
# Adenopathy              0
# Pathology               0
# Focality                0
# Risk                    0
# T                       0
# N                       0
# M                       0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   383 non-null    int64
#  1   Gender                383 non-null    int64
#  2   Smoking               383 non-null    int64
#  3   Hx Smoking            383 non-null    int64
#  4   Hx Radiothreapy       383 non-null    int64
#  5   Thyroid Function      383 non-null    int64
#  6   Physical Examination  383 non-null    int32
#  7   Adenopathy            383 non-null    int32
#  8   Pathology             383 non-null    int32
#  9   Focality              383 non-null    int32
#  10  Risk                  383 non-null    int64
#  11  T                     383 non-null    int64
#  12  N                     383 non-null    int64
#  13  M                     383 non-null    int64
# dtypes: int32(4), int64(10)
# memory usage: 36.0 KB

# %%
x
# Out:
#      Age  Gender  Smoking  Hx Smoking  Hx Radiothreapy  Thyroid Function  \
# 0     27       0        0           0                0                 1
# 1     34       0        0           1                0                 1
# 2     30       0        0           0                0                 1
# 3     62       0        0           0                0                 1
# 4     62       0        0           0                0                 1
# ..   ...     ...      ...         ...              ...               ...
# 378   72       1        1           1                1                 1
# 379   81       1        1           0                1                 1
# 380   72       1        1           1                0                 1
# 381   61       1        1           1                1                 0
# 382   67       1        1           0                0                 1
#
#      Physical Examination  Adenopathy  Pathology  Focality  Risk  T  N  M
# ...
