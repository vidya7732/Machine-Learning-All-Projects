# %%
import pandas as pd
x=pd.read_csv(r"C:\Users\vidya\Downloads\output.csv")
x
# Out:
#      Number Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1   M     43.2555       30.8421      25.9025   6.3     Yes
# 1         2   F     45.6033       28.1900      26.2067  13.5      No
# 2         3  F      45.0107       28.9677      26.0215  11.7      No
# 3         4   F     44.5398       28.9899      26.4703  13.5      No
# 4         5  M      43.2870       30.6972      26.0158  12.4      No
# ..      ...  ..         ...           ...          ...   ...     ...
# 99      100  F      49.9999       29.2860      20.7141  14.5     Yes
# 100     101  M      42.2324       30.6757      27.0919   6.3     Yes
# 101     102   F     45.6064       31.9084      22.4852  12.7      No
# 102     103  M      45.2095       29.2769      25.5136  13.4      No
# 103     104   F     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
x.shape
# Out:
# (104, 7)

# %%
x.isnull().sum()
# Out:
# Number          0
# Sex             0
# %Red Pixel      0
# %Green pixel    0
# %Blue pixel     0
# Hb              0
# Anaemic         0
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Number        104 non-null    int64
#  1   Sex           104 non-null    object
#  2   %Red Pixel    104 non-null    float64
#  3   %Green pixel  104 non-null    float64
#  4   %Blue pixel   104 non-null    float64
#  5   Hb            104 non-null    float64
#  6   Anaemic       104 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 5.8+ KB

# %%
x["Sex"].unique()
# Out:
# array(['M', 'F', 'F ', 'M '], dtype=object)

# %%
x["Sex"].nunique()
# Out:
# 4

# %%
x["Sex"]=x["Sex"].apply(lambda p:p.replace("M","1"))
x["Sex"]=x["Sex"].apply(lambda p:p.replace("F","0"))
x["Sex"]
# Out:
# 0       1
# 1       0
# 2      0
# 3       0
# 4      1
#        ..
# 99     0
# 100    1
# 101     0
# 102    1
# 103     0
# Name: Sex, Length: 104, dtype: object

# %%
x["Sex"]=x["Sex"].astype("int")
x["Sex"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 99     0
# 100    1
# 101    0
# 102    1
# 103    0
# Name: Sex, Length: 104, dtype: int32

# %%
x
# Out:
#      Number  Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb Anaemic
# 0         1    1     43.2555       30.8421      25.9025   6.3     Yes
# 1         2    0     45.6033       28.1900      26.2067  13.5      No
# 2         3    0     45.0107       28.9677      26.0215  11.7      No
# 3         4    0     44.5398       28.9899      26.4703  13.5      No
# 4         5    1     43.2870       30.6972      26.0158  12.4      No
# ..      ...  ...         ...           ...          ...   ...     ...
# 99      100    0     49.9999       29.2860      20.7141  14.5     Yes
# 100     101    1     42.2324       30.6757      27.0919   6.3     Yes
# 101     102    0     45.6064       31.9084      22.4852  12.7      No
# 102     103    1     45.2095       29.2769      25.5136  13.4      No
# 103     104    0     43.5706       29.8094      26.6199  12.2      No
#
# [104 rows x 7 columns]

# %%
x["Anaemic"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
x["Anaemic"]=x["Anaemic"].map({"Yes":1,"No":0})
x["Anaemic"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 99     1
# 100    1
# 101    0
# 102    0
# 103    0
# Name: Anaemic, Length: 104, dtype: int64

# %%
x
# Out:
#      Number  Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb  Anaemic
# 0         1    1     43.2555       30.8421      25.9025   6.3        1
# 1         2    0     45.6033       28.1900      26.2067  13.5        0
# 2         3    0     45.0107       28.9677      26.0215  11.7        0
# 3         4    0     44.5398       28.9899      26.4703  13.5        0
# 4         5    1     43.2870       30.6972      26.0158  12.4        0
# ..      ...  ...         ...           ...          ...   ...      ...
# 99      100    0     49.9999       29.2860      20.7141  14.5        1
# 100     101    1     42.2324       30.6757      27.0919   6.3        1
# 101     102    0     45.6064       31.9084      22.4852  12.7        0
# 102     103    1     45.2095       29.2769      25.5136  13.4        0
# 103     104    0     43.5706       29.8094      26.6199  12.2        0
#
# [104 rows x 7 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Number        104 non-null    int64
#  1   Sex           104 non-null    int32
#  2   %Red Pixel    104 non-null    float64
#  3   %Green pixel  104 non-null    float64
#  4   %Blue pixel   104 non-null    float64
#  5   Hb            104 non-null    float64
#  6   Anaemic       104 non-null    int64
# dtypes: float64(4), int32(1), int64(2)
# memory usage: 5.4 KB

# %%
F=x.drop("Anaemic",axis=1)
T=x["Anaemic"]

# %%
F
# Out:
#      Number  Sex  %Red Pixel  %Green pixel  %Blue pixel    Hb
# 0         1    1     43.2555       30.8421      25.9025   6.3
# 1         2    0     45.6033       28.1900      26.2067  13.5
# 2         3    0     45.0107       28.9677      26.0215  11.7
# 3         4    0     44.5398       28.9899      26.4703  13.5
# 4         5    1     43.2870       30.6972      26.0158  12.4
# ..      ...  ...         ...           ...          ...   ...
# 99      100    0     49.9999       29.2860      20.7141  14.5
# 100     101    1     42.2324       30.6757      27.0919   6.3
# 101     102    0     45.6064       31.9084      22.4852  12.7
# 102     103    1     45.2095       29.2769      25.5136  13.4
# 103     104    0     43.5706       29.8094      26.6199  12.2
#
# [104 rows x 6 columns]

# %%
T
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 99     1
# 100    1
# 101    0
# 102    0
# 103    0
# Name: Anaemic, Length: 104, dtype: int64

# %%
x.corr()
# Out:
#                 Number       Sex  %Red Pixel  %Green pixel  %Blue pixel  \
# Number        1.000000  0.057428    0.286166     -0.077089    -0.345707
# Sex           0.057428  1.000000    0.137778     -0.234813    -0.011616
# %Red Pixel    0.286166  0.137778    1.000000     -0.732003    -0.845764
# %Green pixel -0.077089 -0.234813   -0.732003      1.000000     0.255589
# %Blue pixel  -0.345707 -0.011616   -0.845764      0.255589     1.000000
# Hb           -0.019768  0.254932    0.424586     -0.637340    -0.103373
# Anaemic       0.053997 -0.211307   -0.353376      0.566447     0.057844
#
#                     Hb   Anaemic
# Number       -0.019768  0.053997
# Sex           0.254932 -0.211307
# %Red Pixel    0.424586 -0.353376
# %Green pixel -0.637340  0.566447
# %Blue pixel  -0.103373  0.057844
# Hb            1.000000 -0.766506
# Anaemic      -0.766506  1.000000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(F,T,train_size=0.85,random_state=300)

# %%
X_train.shape
# Out:
# (88, 6)

# %%
X_test.shape
# Out:
# (16, 6)

# %%
y_train.shape
# Out:
# (88,)

# %%
y_test.shape
# Out:
# (16,)

# %%
from sklearn.preprocessing import MinMaxScaler
M=MinMaxScaler()
X_train[["%Red Pixel","%Green pixel","%Blue pixel","Hb"]]=M.fit_transform(X_train[["%Red Pixel","%Green pixel","%Blue pixel","Hb"]])
X_train
# Out:
#     Number  Sex  %Red Pixel  %Green pixel  %Blue pixel        Hb
# 17      18    0    0.350584      0.671989     0.610382  0.407407
# 6        7    0    0.287730      0.694886     0.688070  0.429630
# 82      83    0    0.286923      0.581864     0.770175  0.562963
# 96      97    0    0.845771      0.432704     0.040473  0.770370
# 99     100    0    0.741215      0.573577     0.096137  0.866667
# ..     ...  ...         ...           ...          ...       ...
# 9       10    0    0.510602      0.316542     0.625286  0.511111
# 74      75    1    0.391889      0.400592     0.742813  0.829630
# 21      22    0    0.306044      0.643156     0.697686  0.711111
# 97      98    1    0.633253      0.246507     0.491835  0.718519
# 81      82    0    0.266638      0.542226     0.828908  0.733333
#
# [88 rows x 6 columns]

# %%
X_test[["%Red Pixel","%Green pixel","%Blue pixel","Hb"]]=M.transform(X_test[["%Red Pixel","%Green pixel","%Blue pixel","Hb"]])
X_test
# Out:
#     Number  Sex  %Red Pixel  %Green pixel  %Blue pixel        Hb
# 95      96    1    0.883734      0.130745     0.199780  0.977778
# 7        8    0    0.318469      0.549213     0.746329  0.555556
# 88      89    1    1.048728      0.092781    -0.020004  0.918519
# 50      51    1    0.474319      0.451202     0.583209  0.755556
# 27      28    1    0.366066      0.501038     0.709569  0.837037
# 90      91    0    0.501353      0.517682     0.495162  0.585185
# 11      12    0    0.371127      0.524295     0.685347  0.933333
# 78      79    0    0.241913      0.803080     0.679207  0.474074
# 79      80    0    0.366390      0.728299     0.546420  0.385185
# 34      35    0    0.222038      0.732131     0.759737  0.807407
# 70      71    0    0.357451      0.601248     0.650736  0.622222
# 39      40    1    0.486162      0.355323     0.634109  0.837037
# 52      53    1    0.341824      0.478361     0.762094  0.785185
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.linear_model import LogisticRegression
L=LogisticRegression()
from sklearn.model_selection import GridSearchCV
params={"C":[0.1,0.01,0.2,0.04,0.001],"penalty":["l1","l2"]}
log=GridSearchCV(L,param_grid=params,scoring="accuracy",cv=5)

# %%
log.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.1, 0.01, 0.2, 0.04, 0.001],
#                          'penalty': ['l1', 'l2']},
#              scoring='accuracy')

# %%
log.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l2'}

# %%
log.best_estimator_
# Out:
# LogisticRegression(C=0.1)

# %%
log.score(X_train,y_train)
# Out:
# 0.75

# %%
log.score(X_test,y_test)
# Out:
# 0.75

# %%
from sklearn.svm import SVC
s=SVC()
from sklearn.model_selection import GridSearchCV
params={"C":[.1,0.1,0.01,0.3],"gamma":[.1,.07,.01,1],"kernel":["rbf"]}
SVC=GridSearchCV(s,param_grid=params,scoring="accuracy",cv=7)

# %%
SVC.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=SVC(),
#              param_grid={'C': [0.1, 0.1, 0.01, 0.3],
#                          'gamma': [0.1, 0.07, 0.01, 1], 'kernel': ['rbf']},
#              scoring='accuracy')

# %%
SVC.best_params_
# Out:
# {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
SVC.best_estimator_
# Out:
# SVC(C=0.1, gamma=0.1)

# %%
SVC.score(X_train,y_train)
# Out:
# 0.75

# %%
SVC.score(X_test,y_test)
# Out:
# 0.75

# %%
from sklearn.neighbors import KNeighborsClassifier
A=KNeighborsClassifier()
from sklearn.model_selection import GridSearchCV
knn=GridSearchCV(A,param_grid={"n_neighbors":[3,5,7,9]},scoring="accuracy",cv=5)

# %%
knn.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9]}, scoring='accuracy')

# %%
knn.best_params_
# Out:
# {'n_neighbors': 9}

# %%
knn.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
knn.score(X_train,y_train)
# Out:
# 0.7613636363636364

# %%
knn.score(X_test,y_test)
# Out:
# 0.6875

# %%
A={"models":["log","SVC","knn"],"Train":[0.75,0.75,0.76],"Test":[0.75,0.75,0.68]}

# %%
A=pd.DataFrame(A)
A
# Out:
#   models  Train  Test
# 0    log   0.75  0.75
# 1    SVC   0.75  0.75
# 2    knn   0.76  0.68

# %%
import matplotlib.pyplot as plt
plt.bar(A["models"],A["Train"],color="black",width=0.3,align="edge",label="Training Accuracy")
plt.bar(A["models"],A["Test"],color="red",width=0.3,align="center",label="Testing Accuracy")
plt.xlabel("models")
plt.ylabel("accuracy")
plt.title("Model Performance")
plt.legend()
plt.show()
